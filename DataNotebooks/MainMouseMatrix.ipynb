# %%
import pandas as pd
import anndata
import math
import os

# Define an output directory for the section files
output_dir = r"D:\Mouse\Matrices"
os.makedirs(output_dir, exist_ok=True)

# %%
# Load cell metadata
metadata = pd.read_csv(
    r"D:\Mouse\GeneExpressions\metadata\MERFISH-C57BL6J-638850-CCF\20231215\views\cell_metadata_with_parcellation_annotation.csv",
    usecols=['cell_label','brain_section_label','neurotransmitter', 'class','subclass',
             'parcellation_index', 'parcellation_division', 'parcellation_structure', 'parcellation_substructure',
             'cluster_alias','average_correlation_score',
             'x_reconstructed','y_reconstructed','z_reconstructed']
             )
# Out:
# Empty DataFrame
# Columns: [cell_label, brain_section_label, cluster_alias, average_correlation_score, neurotransmitter, class, subclass, x_reconstructed, y_reconstructed, z_reconstructed, parcellation_index, parcellation_division, parcellation_structure, parcellation_substructure]
# Index: []

# %%
print(metadata[metadata['parcellation_division']=='Isocortex'].shape)
# Out:
# (935742, 14)

# %%
# Load cell metadata
metadata = pd.read_csv(
    r"D:\Mouse\GeneExpressions\metadata\MERFISH-C57BL6J-638850-CCF\20231215\views\cell_metadata_with_parcellation_annotation.csv",
    usecols=['cell_label','brain_section_label','neurotransmitter', 'class','subclass',
             'parcellation_index', 'parcellation_division', 'parcellation_structure', 'parcellation_substructure',
             'cluster_alias','average_correlation_score',
             'x_reconstructed','y_reconstructed','z_reconstructed']
)

# Set the index to 'cell_label' so it matches exprData.obs_names
metadata_indexed = metadata.set_index('cell_label')
columns_to_join = ['neurotransmitter', 'class','subclass',
                    'parcellation_index', 'parcellation_division', 'parcellation_structure', 'parcellation_substructure',
                    'cluster_alias','average_correlation_score',
                    'x_reconstructed','y_reconstructed','z_reconstructed']
metadata_indexed = metadata_indexed[columns_to_join]

# Get the list of brain sections
brain_sections = sorted(metadata['brain_section_label'].unique())

# Load the expression data
geneImputedExpression = r"D:\Mouse\GeneExpressions\expression_matrices\MERFISH-C57BL6J-638850-imputed\20240831\C57BL6J-638850-imputed-log2.h5ad"
exprData = anndata.read_h5ad(geneImputedExpression, backed='r')

# %%
# Process each brain section
for brain_section in brain_sections:
    print(f"Processing {brain_section}")
    
    # Get cell labels for the current brain section from the metadata
    cellsMet = metadata.loc[metadata['brain_section_label'] == brain_section, 'cell_label'].tolist()
    print(f"Found {len(cellsMet)} cells in {brain_section}")
    
    # Find the intersection between these cell labels and the AnnData obs_names
    cellsExpr = exprData.obs_names.intersection(cellsMet)
    print(f"Found {len(cellsExpr)} cells in the expression data")
    
    # Determine chunking parameters (process 1/20 of cells at a time)
    n_cells = len(cellsExpr)
    n_chunks = 12
    chunk_size = math.ceil(n_cells / n_chunks)
    chunk_files = []
    
    # Process cells in chunks
    for i in range(n_chunks):
        start = i * chunk_size
        end = min((i + 1) * chunk_size, n_cells)
        chunk_cell_names = cellsExpr[start:end].tolist()
        if not chunk_cell_names:
            break
        print(f"Processing chunk {i+1} with {len(chunk_cell_names)} cells.")
        
        # Subset the expression data for these cells and load into memory
        chunkData = exprData[chunk_cell_names, :].to_memory()
        
        # Combine metadata with the AnnData object's .obs dataframe
        chunkData.obs = chunkData.obs.join(metadata_indexed, how='left')
        
        # Convert problematic columns (e.g., 'neurotransmitter') to string to avoid h5py errors
        for col in chunkData.obs.select_dtypes(include=['object']).columns:
            chunkData.obs[col] = chunkData.obs[col].astype(str)
        
        # Define a temporary filename for this chunk and save it
        chunk_filename = os.path.join(output_dir, f"{brain_section}_chunk_{i+1}.h5ad")
        chunkData.write(chunk_filename)
        chunk_files.append(chunk_filename)
        print(f"Saved {chunk_filename}")
    
    # Now, load all chunk files and concatenate them into one AnnData object
    chunk_adatas = [anndata.read_h5ad(chunk_file) for chunk_file in chunk_files]
    combined_sectionData = anndata.concat(chunk_adatas, join='outer', merge='same')
    
    # Save the combined section data
    final_filename = os.path.join(output_dir, f"{brain_section}.h5ad")
    combined_sectionData.write(final_filename)
    print(f"Saved combined section data as {final_filename}")
    
    # Delete temporary chunk files
    for chunk_file in chunk_files:
        os.remove(chunk_file)
        print(f"Deleted temporary file {chunk_file}")
# Out:
# Processing C57BL6J-638850.05
# Found 45915 cells in C57BL6J-638850.05
# Found 45915 cells in the expression data
# Processing chunk 1 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_1.h5ad
# Processing chunk 2 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_2.h5ad
# Processing chunk 3 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_3.h5ad
# Processing chunk 4 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_4.h5ad
# Processing chunk 5 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_5.h5ad
# Processing chunk 6 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_6.h5ad
# Processing chunk 7 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_7.h5ad
# Processing chunk 8 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_8.h5ad
# Processing chunk 9 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_9.h5ad
# Processing chunk 10 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_10.h5ad
# Processing chunk 11 with 3827 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_11.h5ad
# Processing chunk 12 with 3818 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.05_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.05.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.05_chunk_12.h5ad
# Processing C57BL6J-638850.06
# Found 46526 cells in C57BL6J-638850.06
# Found 46526 cells in the expression data
# Processing chunk 1 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_1.h5ad
# Processing chunk 2 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_2.h5ad
# Processing chunk 3 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_3.h5ad
# Processing chunk 4 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_4.h5ad
# Processing chunk 5 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_5.h5ad
# Processing chunk 6 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_6.h5ad
# Processing chunk 7 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_7.h5ad
# Processing chunk 8 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_8.h5ad
# Processing chunk 9 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_9.h5ad
# Processing chunk 10 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_10.h5ad
# Processing chunk 11 with 3878 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_11.h5ad
# Processing chunk 12 with 3868 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.06_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.06.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.06_chunk_12.h5ad
# Processing C57BL6J-638850.08
# Found 47009 cells in C57BL6J-638850.08
# Found 47009 cells in the expression data
# Processing chunk 1 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_1.h5ad
# Processing chunk 2 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_2.h5ad
# Processing chunk 3 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_3.h5ad
# Processing chunk 4 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_4.h5ad
# Processing chunk 5 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_5.h5ad
# Processing chunk 6 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_6.h5ad
# Processing chunk 7 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_7.h5ad
# Processing chunk 8 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_8.h5ad
# Processing chunk 9 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_9.h5ad
# Processing chunk 10 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_10.h5ad
# Processing chunk 11 with 3918 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_11.h5ad
# Processing chunk 12 with 3911 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.08_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.08.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.08_chunk_12.h5ad
# Processing C57BL6J-638850.09
# Found 69235 cells in C57BL6J-638850.09
# Found 69235 cells in the expression data
# Processing chunk 1 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_1.h5ad
# Processing chunk 2 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_2.h5ad
# Processing chunk 3 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_3.h5ad
# Processing chunk 4 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_4.h5ad
# Processing chunk 5 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_5.h5ad
# Processing chunk 6 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_6.h5ad
# Processing chunk 7 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_7.h5ad
# Processing chunk 8 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_8.h5ad
# Processing chunk 9 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_9.h5ad
# Processing chunk 10 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_10.h5ad
# Processing chunk 11 with 5770 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_11.h5ad
# Processing chunk 12 with 5765 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.09_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.09.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.09_chunk_12.h5ad
# Processing C57BL6J-638850.10
# Found 42098 cells in C57BL6J-638850.10
# Found 42098 cells in the expression data
# Processing chunk 1 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_1.h5ad
# Processing chunk 2 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_2.h5ad
# Processing chunk 3 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_3.h5ad
# Processing chunk 4 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_4.h5ad
# Processing chunk 5 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_5.h5ad
# Processing chunk 6 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_6.h5ad
# Processing chunk 7 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_7.h5ad
# Processing chunk 8 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_8.h5ad
# Processing chunk 9 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_9.h5ad
# Processing chunk 10 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_10.h5ad
# Processing chunk 11 with 3509 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_11.h5ad
# Processing chunk 12 with 3499 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.10_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.10_chunk_12.h5ad
# Processing C57BL6J-638850.11
# Found 47690 cells in C57BL6J-638850.11
# Found 47690 cells in the expression data
# Processing chunk 1 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_1.h5ad
# Processing chunk 2 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_2.h5ad
# Processing chunk 3 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_3.h5ad
# Processing chunk 4 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_4.h5ad
# Processing chunk 5 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_5.h5ad
# Processing chunk 6 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_6.h5ad
# Processing chunk 7 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_7.h5ad
# Processing chunk 8 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_8.h5ad
# Processing chunk 9 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_9.h5ad
# Processing chunk 10 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_10.h5ad
# Processing chunk 11 with 3975 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_11.h5ad
# Processing chunk 12 with 3965 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.11_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.11_chunk_12.h5ad
# Processing C57BL6J-638850.12
# Found 50612 cells in C57BL6J-638850.12
# Found 50612 cells in the expression data
# Processing chunk 1 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_1.h5ad
# Processing chunk 2 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_2.h5ad
# Processing chunk 3 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_3.h5ad
# Processing chunk 4 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_4.h5ad
# Processing chunk 5 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_5.h5ad
# Processing chunk 6 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_6.h5ad
# Processing chunk 7 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_7.h5ad
# Processing chunk 8 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_8.h5ad
# Processing chunk 9 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_9.h5ad
# Processing chunk 10 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_10.h5ad
# Processing chunk 11 with 4218 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_11.h5ad
# Processing chunk 12 with 4214 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.12_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.12.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.12_chunk_12.h5ad
# Processing C57BL6J-638850.13
# Found 71231 cells in C57BL6J-638850.13
# Found 71231 cells in the expression data
# Processing chunk 1 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_1.h5ad
# Processing chunk 2 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_2.h5ad
# Processing chunk 3 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_3.h5ad
# Processing chunk 4 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_4.h5ad
# Processing chunk 5 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_5.h5ad
# Processing chunk 6 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_6.h5ad
# Processing chunk 7 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_7.h5ad
# Processing chunk 8 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_8.h5ad
# Processing chunk 9 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_9.h5ad
# Processing chunk 10 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_10.h5ad
# Processing chunk 11 with 5936 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_11.h5ad
# Processing chunk 12 with 5935 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.13_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.13.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.13_chunk_12.h5ad
# Processing C57BL6J-638850.14
# Found 94385 cells in C57BL6J-638850.14
# Found 94385 cells in the expression data
# Processing chunk 1 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_1.h5ad
# Processing chunk 2 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_2.h5ad
# Processing chunk 3 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_3.h5ad
# Processing chunk 4 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_4.h5ad
# Processing chunk 5 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_5.h5ad
# Processing chunk 6 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_6.h5ad
# Processing chunk 7 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_7.h5ad
# Processing chunk 8 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_8.h5ad
# Processing chunk 9 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_9.h5ad
# Processing chunk 10 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_10.h5ad
# Processing chunk 11 with 7866 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_11.h5ad
# Processing chunk 12 with 7859 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.14_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.14.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.14_chunk_12.h5ad
# Processing C57BL6J-638850.15
# Found 80333 cells in C57BL6J-638850.15
# Found 80333 cells in the expression data
# Processing chunk 1 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_1.h5ad
# Processing chunk 2 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_2.h5ad
# Processing chunk 3 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_3.h5ad
# Processing chunk 4 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_4.h5ad
# Processing chunk 5 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_5.h5ad
# Processing chunk 6 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_6.h5ad
# Processing chunk 7 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_7.h5ad
# Processing chunk 8 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_8.h5ad
# Processing chunk 9 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_9.h5ad
# Processing chunk 10 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_10.h5ad
# Processing chunk 11 with 6695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_11.h5ad
# Processing chunk 12 with 6688 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.15_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.15.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.15_chunk_12.h5ad
# Processing C57BL6J-638850.16
# Found 80453 cells in C57BL6J-638850.16
# Found 80453 cells in the expression data
# Processing chunk 1 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_1.h5ad
# Processing chunk 2 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_2.h5ad
# Processing chunk 3 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_3.h5ad
# Processing chunk 4 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_4.h5ad
# Processing chunk 5 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_5.h5ad
# Processing chunk 6 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_6.h5ad
# Processing chunk 7 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_7.h5ad
# Processing chunk 8 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_8.h5ad
# Processing chunk 9 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_9.h5ad
# Processing chunk 10 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_10.h5ad
# Processing chunk 11 with 6705 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_11.h5ad
# Processing chunk 12 with 6698 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.16_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.16.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.16_chunk_12.h5ad
# Processing C57BL6J-638850.17
# Found 58893 cells in C57BL6J-638850.17
# Found 58893 cells in the expression data
# Processing chunk 1 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_1.h5ad
# Processing chunk 2 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_2.h5ad
# Processing chunk 3 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_3.h5ad
# Processing chunk 4 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_4.h5ad
# Processing chunk 5 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_5.h5ad
# Processing chunk 6 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_6.h5ad
# Processing chunk 7 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_7.h5ad
# Processing chunk 8 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_8.h5ad
# Processing chunk 9 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_9.h5ad
# Processing chunk 10 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_10.h5ad
# Processing chunk 11 with 4908 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_11.h5ad
# Processing chunk 12 with 4905 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.17_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.17.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.17_chunk_12.h5ad
# Processing C57BL6J-638850.18
# Found 44338 cells in C57BL6J-638850.18
# Found 44338 cells in the expression data
# Processing chunk 1 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_1.h5ad
# Processing chunk 2 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_2.h5ad
# Processing chunk 3 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_3.h5ad
# Processing chunk 4 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_4.h5ad
# Processing chunk 5 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_5.h5ad
# Processing chunk 6 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_6.h5ad
# Processing chunk 7 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_7.h5ad
# Processing chunk 8 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_8.h5ad
# Processing chunk 9 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_9.h5ad
# Processing chunk 10 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_10.h5ad
# Processing chunk 11 with 3695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_11.h5ad
# Processing chunk 12 with 3693 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.18_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.18.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.18_chunk_12.h5ad
# Processing C57BL6J-638850.19
# Found 61618 cells in C57BL6J-638850.19
# Found 61618 cells in the expression data
# Processing chunk 1 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_1.h5ad
# Processing chunk 2 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_2.h5ad
# Processing chunk 3 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_3.h5ad
# Processing chunk 4 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_4.h5ad
# Processing chunk 5 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_5.h5ad
# Processing chunk 6 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_6.h5ad
# Processing chunk 7 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_7.h5ad
# Processing chunk 8 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_8.h5ad
# Processing chunk 9 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_9.h5ad
# Processing chunk 10 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_10.h5ad
# Processing chunk 11 with 5135 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_11.h5ad
# Processing chunk 12 with 5133 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.19_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.19.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.19_chunk_12.h5ad
# Processing C57BL6J-638850.24
# Found 61621 cells in C57BL6J-638850.24
# Found 61621 cells in the expression data
# Processing chunk 1 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_1.h5ad
# Processing chunk 2 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_2.h5ad
# Processing chunk 3 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_3.h5ad
# Processing chunk 4 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_4.h5ad
# Processing chunk 5 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_5.h5ad
# Processing chunk 6 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_6.h5ad
# Processing chunk 7 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_7.h5ad
# Processing chunk 8 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_8.h5ad
# Processing chunk 9 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_9.h5ad
# Processing chunk 10 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_10.h5ad
# Processing chunk 11 with 5136 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_11.h5ad
# Processing chunk 12 with 5125 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.24_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.24.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.24_chunk_12.h5ad
# Processing C57BL6J-638850.25
# Found 73779 cells in C57BL6J-638850.25
# Found 73779 cells in the expression data
# Processing chunk 1 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_1.h5ad
# Processing chunk 2 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_2.h5ad
# Processing chunk 3 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_3.h5ad
# Processing chunk 4 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_4.h5ad
# Processing chunk 5 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_5.h5ad
# Processing chunk 6 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_6.h5ad
# Processing chunk 7 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_7.h5ad
# Processing chunk 8 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_8.h5ad
# Processing chunk 9 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_9.h5ad
# Processing chunk 10 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_10.h5ad
# Processing chunk 11 with 6149 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_11.h5ad
# Processing chunk 12 with 6140 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.25_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.25.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.25_chunk_12.h5ad
# Processing C57BL6J-638850.26
# Found 79307 cells in C57BL6J-638850.26
# Found 79307 cells in the expression data
# Processing chunk 1 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_1.h5ad
# Processing chunk 2 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_2.h5ad
# Processing chunk 3 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_3.h5ad
# Processing chunk 4 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_4.h5ad
# Processing chunk 5 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_5.h5ad
# Processing chunk 6 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_6.h5ad
# Processing chunk 7 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_7.h5ad
# Processing chunk 8 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_8.h5ad
# Processing chunk 9 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_9.h5ad
# Processing chunk 10 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_10.h5ad
# Processing chunk 11 with 6609 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_11.h5ad
# Processing chunk 12 with 6608 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.26_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.26.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.26_chunk_12.h5ad
# Processing C57BL6J-638850.27
# Found 49921 cells in C57BL6J-638850.27
# Found 49921 cells in the expression data
# Processing chunk 1 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_1.h5ad
# Processing chunk 2 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_2.h5ad
# Processing chunk 3 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_3.h5ad
# Processing chunk 4 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_4.h5ad
# Processing chunk 5 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_5.h5ad
# Processing chunk 6 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_6.h5ad
# Processing chunk 7 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_7.h5ad
# Processing chunk 8 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_8.h5ad
# Processing chunk 9 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_9.h5ad
# Processing chunk 10 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_10.h5ad
# Processing chunk 11 with 4161 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_11.h5ad
# Processing chunk 12 with 4150 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.27_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.27.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.27_chunk_12.h5ad
# Processing C57BL6J-638850.28
# Found 79139 cells in C57BL6J-638850.28
# Found 79139 cells in the expression data
# Processing chunk 1 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_1.h5ad
# Processing chunk 2 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_2.h5ad
# Processing chunk 3 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_3.h5ad
# Processing chunk 4 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_4.h5ad
# Processing chunk 5 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_5.h5ad
# Processing chunk 6 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_6.h5ad
# Processing chunk 7 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_7.h5ad
# Processing chunk 8 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_8.h5ad
# Processing chunk 9 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_9.h5ad
# Processing chunk 10 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_10.h5ad
# Processing chunk 11 with 6595 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_11.h5ad
# Processing chunk 12 with 6594 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.28_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.28.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.28_chunk_12.h5ad
# Processing C57BL6J-638850.29
# Found 77777 cells in C57BL6J-638850.29
# Found 77777 cells in the expression data
# Processing chunk 1 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_1.h5ad
# Processing chunk 2 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_2.h5ad
# Processing chunk 3 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_3.h5ad
# Processing chunk 4 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_4.h5ad
# Processing chunk 5 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_5.h5ad
# Processing chunk 6 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_6.h5ad
# Processing chunk 7 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_7.h5ad
# Processing chunk 8 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_8.h5ad
# Processing chunk 9 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_9.h5ad
# Processing chunk 10 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_10.h5ad
# Processing chunk 11 with 6482 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_11.h5ad
# Processing chunk 12 with 6475 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.29_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.29.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.29_chunk_12.h5ad
# Processing C57BL6J-638850.30
# Found 91051 cells in C57BL6J-638850.30
# Found 91051 cells in the expression data
# Processing chunk 1 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_1.h5ad
# Processing chunk 2 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_2.h5ad
# Processing chunk 3 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_3.h5ad
# Processing chunk 4 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_4.h5ad
# Processing chunk 5 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_5.h5ad
# Processing chunk 6 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_6.h5ad
# Processing chunk 7 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_7.h5ad
# Processing chunk 8 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_8.h5ad
# Processing chunk 9 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_9.h5ad
# Processing chunk 10 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_10.h5ad
# Processing chunk 11 with 7588 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_11.h5ad
# Processing chunk 12 with 7583 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.30_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.30.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.30_chunk_12.h5ad
# Processing C57BL6J-638850.31
# Found 91988 cells in C57BL6J-638850.31
# Found 91988 cells in the expression data
# Processing chunk 1 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_1.h5ad
# Processing chunk 2 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_2.h5ad
# Processing chunk 3 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_3.h5ad
# Processing chunk 4 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_4.h5ad
# Processing chunk 5 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_5.h5ad
# Processing chunk 6 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_6.h5ad
# Processing chunk 7 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_7.h5ad
# Processing chunk 8 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_8.h5ad
# Processing chunk 9 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_9.h5ad
# Processing chunk 10 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_10.h5ad
# Processing chunk 11 with 7666 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_11.h5ad
# Processing chunk 12 with 7662 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.31_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.31.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.31_chunk_12.h5ad
# Processing C57BL6J-638850.32
# Found 93489 cells in C57BL6J-638850.32
# Found 93489 cells in the expression data
# Processing chunk 1 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_1.h5ad
# Processing chunk 2 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_2.h5ad
# Processing chunk 3 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_3.h5ad
# Processing chunk 4 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_4.h5ad
# Processing chunk 5 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_5.h5ad
# Processing chunk 6 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_6.h5ad
# Processing chunk 7 with 7791 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.32_chunk_7.h5ad
# Processing chunk 8 with 7791 cells.
# ...
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.58.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.58_chunk_12.h5ad
# Processing C57BL6J-638850.59
# Found 37482 cells in C57BL6J-638850.59
# Found 37482 cells in the expression data
# Processing chunk 1 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_1.h5ad
# Processing chunk 2 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_2.h5ad
# Processing chunk 3 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_3.h5ad
# Processing chunk 4 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_4.h5ad
# Processing chunk 5 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_5.h5ad
# Processing chunk 6 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_6.h5ad
# Processing chunk 7 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_7.h5ad
# Processing chunk 8 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_8.h5ad
# Processing chunk 9 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_9.h5ad
# Processing chunk 10 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_10.h5ad
# Processing chunk 11 with 3124 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_11.h5ad
# Processing chunk 12 with 3118 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.59_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.59.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.59_chunk_12.h5ad
# Processing C57BL6J-638850.60
# Found 33435 cells in C57BL6J-638850.60
# Found 33435 cells in the expression data
# Processing chunk 1 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_1.h5ad
# Processing chunk 2 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_2.h5ad
# Processing chunk 3 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_3.h5ad
# Processing chunk 4 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_4.h5ad
# Processing chunk 5 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_5.h5ad
# Processing chunk 6 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_6.h5ad
# Processing chunk 7 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_7.h5ad
# Processing chunk 8 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_8.h5ad
# Processing chunk 9 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_9.h5ad
# Processing chunk 10 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_10.h5ad
# Processing chunk 11 with 2787 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_11.h5ad
# Processing chunk 12 with 2778 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.60_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.60.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.60_chunk_12.h5ad
# Processing C57BL6J-638850.61
# Found 32395 cells in C57BL6J-638850.61
# Found 32395 cells in the expression data
# Processing chunk 1 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_1.h5ad
# Processing chunk 2 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_2.h5ad
# Processing chunk 3 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_3.h5ad
# Processing chunk 4 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_4.h5ad
# Processing chunk 5 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_5.h5ad
# Processing chunk 6 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_6.h5ad
# Processing chunk 7 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_7.h5ad
# Processing chunk 8 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_8.h5ad
# Processing chunk 9 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_9.h5ad
# Processing chunk 10 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_10.h5ad
# Processing chunk 11 with 2700 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_11.h5ad
# Processing chunk 12 with 2695 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.61_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.61.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.61_chunk_12.h5ad
# Processing C57BL6J-638850.62
# Found 33134 cells in C57BL6J-638850.62
# Found 33134 cells in the expression data
# Processing chunk 1 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_1.h5ad
# Processing chunk 2 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_2.h5ad
# Processing chunk 3 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_3.h5ad
# Processing chunk 4 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_4.h5ad
# Processing chunk 5 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_5.h5ad
# Processing chunk 6 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_6.h5ad
# Processing chunk 7 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_7.h5ad
# Processing chunk 8 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_8.h5ad
# Processing chunk 9 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_9.h5ad
# Processing chunk 10 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_10.h5ad
# Processing chunk 11 with 2762 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_11.h5ad
# Processing chunk 12 with 2752 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.62_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.62.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.62_chunk_12.h5ad
# Processing C57BL6J-638850.64
# Found 22273 cells in C57BL6J-638850.64
# Found 22273 cells in the expression data
# Processing chunk 1 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_1.h5ad
# Processing chunk 2 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_2.h5ad
# Processing chunk 3 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_3.h5ad
# Processing chunk 4 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_4.h5ad
# Processing chunk 5 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_5.h5ad
# Processing chunk 6 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_6.h5ad
# Processing chunk 7 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_7.h5ad
# Processing chunk 8 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_8.h5ad
# Processing chunk 9 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_9.h5ad
# Processing chunk 10 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_10.h5ad
# Processing chunk 11 with 1857 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_11.h5ad
# Processing chunk 12 with 1846 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.64_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.64.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.64_chunk_12.h5ad
# Processing C57BL6J-638850.66
# Found 26209 cells in C57BL6J-638850.66
# Found 26209 cells in the expression data
# Processing chunk 1 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_1.h5ad
# Processing chunk 2 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_2.h5ad
# Processing chunk 3 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_3.h5ad
# Processing chunk 4 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_4.h5ad
# Processing chunk 5 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_5.h5ad
# Processing chunk 6 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_6.h5ad
# Processing chunk 7 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_7.h5ad
# Processing chunk 8 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_8.h5ad
# Processing chunk 9 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_9.h5ad
# Processing chunk 10 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_10.h5ad
# Processing chunk 11 with 2185 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_11.h5ad
# Processing chunk 12 with 2174 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.66_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.66.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.66_chunk_12.h5ad
# Processing C57BL6J-638850.67
# Found 29244 cells in C57BL6J-638850.67
# Found 29244 cells in the expression data
# Processing chunk 1 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_1.h5ad
# Processing chunk 2 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_2.h5ad
# Processing chunk 3 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_3.h5ad
# Processing chunk 4 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_4.h5ad
# Processing chunk 5 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_5.h5ad
# Processing chunk 6 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_6.h5ad
# Processing chunk 7 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_7.h5ad
# Processing chunk 8 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_8.h5ad
# Processing chunk 9 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_9.h5ad
# Processing chunk 10 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_10.h5ad
# Processing chunk 11 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_11.h5ad
# Processing chunk 12 with 2437 cells.
# Saved D:\Mouse\Matrices\C57BL6J-638850.67_chunk_12.h5ad
# Saved combined section data as D:\Mouse\Matrices\C57BL6J-638850.67.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_1.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_2.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_3.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_4.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_5.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_6.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_7.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_8.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_9.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_10.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_11.h5ad
# Deleted temporary file D:\Mouse\Matrices\C57BL6J-638850.67_chunk_12.h5ad

# %%
# Load the .h5ad file
adata = anndata.read_h5ad(r"D:\Mouse\Matrices\C57BL6J-638850.05.h5ad")

# Print the shape of the data matrix (observations x variables)
print("Shape (observations, variables):", adata.shape)

# Print a summary of the AnnData object
print(adata)
# Out:
# Shape (observations, variables): (45915, 8460)
# AnnData object with n_obs × n_vars = 45915 × 8460
#     obs: 'brain_section_label', 'neurotransmitter', 'class', 'subclass', 'parcellation_index', 'parcellation_division', 'parcellation_structure', 'parcellation_substructure', 'cluster_alias', 'average_correlation_score', 'x_reconstructed', 'y_reconstructed', 'z_reconstructed'
#     var: 'gene_symbol'

# %%
# Explore the structure:
print("Observation metadata (obs):")
print(adata.obs.head())
# Out:
# Observation metadata (obs):
#                     brain_section_label                     subclass  \
# cell_label
# 1019171911100960969   C57BL6J-638850.05  106 PVpo-VMPO-MPN Hmx2 Gaba
# 1019171911101270462   C57BL6J-638850.05     216 MB-MY Tph2 Glut-Sero
# 1019171911101270488   C57BL6J-638850.05     216 MB-MY Tph2 Glut-Sero
# 1019171911101270469   C57BL6J-638850.05     216 MB-MY Tph2 Glut-Sero
# 1019171911101270478   C57BL6J-638850.05     216 MB-MY Tph2 Glut-Sero
#
#                     parcellation_structure  x_reconstructed  y_reconstructed  \
# cell_label
# 1019171911100960969                    NTS         5.013879         6.247225
# 1019171911101270462          MY-unassigned         5.442881         7.231411
# 1019171911101270488          MY-unassigned         5.424471         7.249722
# 1019171911101270469          MY-unassigned         5.424150         7.233354
# 1019171911101270478          MY-unassigned         5.439546         7.242881
#
#                      z_reconstructed
# cell_label
# 1019171911100960969              0.8
# 1019171911101270462              0.8
# 1019171911101270488              0.8
# 1019171911101270469              0.8
# 1019171911101270478              0.8

# %%
print("\nVariable metadata (var):")
print(adata.var.head())
# Out:
# Variable metadata (var):
#                    gene_symbol
# gene_identifier
# ENSMUSG00000026676       Ccdc3
# ENSMUSG00000024517         Grp
# ENSMUSG00000029361        Nos1
# ENSMUSG00000062372        Otof
# ENSMUSG00000055639       Dach1

# %%
print("\nUnstructured annotations (uns) keys:")
print(adata.uns.keys())
# Out:
# Unstructured annotations (uns) keys:
# odict_keys([])
